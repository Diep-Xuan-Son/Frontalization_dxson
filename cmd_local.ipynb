# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/mqsolutions/frontalization
# Out:
# /content/drive/MyDrive/mqsolutions/frontalization

# %%
# !pwd
# Out:
# /content

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !sudo cp /content/drive/MyDrive/mqsolutions/frontalization/data_1000folder_facebook.zip /content/

# %%
# !sudo rm /content/data1/Facebook/ids1229.jpg

# %%
# !sudo cp /content/data1/Facebook/ids1229/ids1229_2.jpg /content/data1/Facebook/ids1229.jpg

# %%
# !unzip data_1000folder_facebook.zip

# %%
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist --upgrade nvidia-dali-cuda110
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist --upgrade nvidia-dali-tf-plugin-cuda110
# Out:
# Looking in indexes: https://pypi.org/simple, https://developer.download.nvidia.com/compute/redist
# ...
#      |████████████████████████████████| 314.9 MB 4.8 kB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://developer.download.nvidia.com/compute/redist
# ...
#      |████████████████████████████████| 429 kB 38.1 MB/s
# ...
#   Created wheel for nvidia-dali-tf-plugin-cuda110: filename=nvidia_dali_tf_plugin_cuda110-1.13.0-cp37-cp37m-linux_x86_64.whl size=128575 sha256=dcfefed5fea65569c293f2bd7a1c309ed6e8fc000b17008ed736aba8b8614117
#   Stored in directory: /root/.cache/pip/wheels/e6/7c/ea/591c063472f83d025f23cb8bfad6855f7686941b41d2ce2dd0
# Successfully built nvidia-dali-tf-plugin-cuda110
# ...

# %%
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist/nightly --upgrade nvidia-dali-nightly-cuda110
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist/nightly --upgrade nvidia-dali-tf-plugin-nightly-cuda110

# %%
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist/weekly --upgrade nvidia-dali-weekly-cuda110
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist/weekly --upgrade nvidia-dali-tf-plugin-weekly-cuda110

# %%
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist/cuda/11.0 --upgrade nvidia-dali
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist/cuda/11.0 --upgrade nvidia-dali-tf-plugin

# %%
# # Read in the file
# with open('/usr/local/lib/python3.7/dist-packages/nvidia/dali/ops.py', 'r') as file :
#   filedata = file.read()

# # Replace the target string
# filedata = filedata.replace('image_decoder', 'decoders.image')

# # Write the file out again
# with open('/usr/local/lib/python3.7/dist-packages/nvidia/dali/ops.py', 'w') as file:
#   file.write(filedata)

# %%
# !python3 test.py

# %%
import os
import cv2
import shutil

# img = cv2.imread('/home/son/AI/frontalization/data1/Facebook/ids3133/ids3133_1.jpg')
# cv2.imshow('a',img)
# cv2.waitKey()
for root, dirs, files in os.walk('/home/son/AI/frontalization/data1/Facebook/ids3133'):
	for file in files:
		if file.endswith(('.jpg', '.JPG')):
			print(root)
			if len(root.split('/')) < len('/home/son/AI/frontalization/data/Facebook/ids'.split('/')):
				with open(os.path.join(root, file), 'rb') as f:
					check_chars = f.read()[-2:]
				if check_chars != b'\xff\xd9':
					print('Not complete image-----------------------------------------------------')
					os.remove(os.path.join(root, file))
					file_new = file.split('.')[0] + '/' + file.split('.')[0] + '_1.jpg'
					shutil.copy2(os.path.join(root, file_new), os.path.join(root, file))
				continue
			path = os.path.join(root, file)
			with open(path, 'rb') as f:
				check_chars = f.read()[-2:]
			if check_chars != b'\xff\xd9':
				print('Not complete image-----------------------------------------------------')
				os.remove(path)
				continue
			print(path)
			img = cv2.imread(path)
			dim = (128, 128)
			# resize image
			resided = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
			cv2.imwrite(path,resided)

# %%
# !python3 main_test.py
# Out:
# /content/drive/MyDrive/mqsolutions/frontalization/data_test.py:140: DeprecationWarning: The argument ``output_dtype`` is a deprecated alias for ``dtype``. Use ``dtype`` instead.
#   crop_h=image_size, crop_w=image_size)
# /content/drive/MyDrive/mqsolutions/frontalization/data_test.py:140: DeprecationWarning: The argument ``image_type`` is no longer used and will be removed in a future release.
#   crop_h=image_size, crop_w=image_size)
# /usr/local/lib/python3.7/dist-packages/nvidia/dali/ops.py:611: DeprecationWarning: WARNING: `image_decoder` is now deprecated. Use `decoders.image` instead.
# In DALI 1.0 all decoders were moved into a dedicated :mod:`~nvidia.dali.fn.decoders`
# submodule and renamed to follow a common pattern. This is a placeholder operator with identical
# functionality to allow for backward compatibility.
#   op_instances.append(_OperatorInstance(input_set, self, **kwargs))
# ...
